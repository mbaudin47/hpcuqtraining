# %% [markdown]
# # Calibration of the Chaboche mecanical model with bayesian methods
#
# ## Abstract
#
# In this exercise, we define a mecanical model and perform the calibration of the model using bayesian methods. More precisely we use a Gaussian prior and use non linear and linear methods in order to calibrate three parameters of the model.
#
# ## Deterministic model
#
# The Chaboche mecanical law predicts the stress depending on the strain:
# $$
# \sigma = G(\epsilon,R,C,\gamma) = R + \frac{C}{\gamma} (1-\exp(-\gamma\epsilon))
# $$
#
# where:
#
# - $\epsilon$ is the strain,
# - $\sigma$ is the stress (Pa),
# - $R$, $C$, $\gamma$ are the parameters.
#
# The variables have the following distributions and are supposed to be independent.
#
# | Random var. | Distribution |
# |--|--|
# | $R$ | Lognormal ($\mu = 750$ MPa, $\sigma = 11$ MPa) |
# | $C$ | Normal ($\mu = 2750$ MPa, $\sigma = 250$ MPa) |
# | $\gamma$ | Normal ($\mu = 10$, $\sigma = 2$) |
# | $\epsilon$ | Uniform(a=0, b=0.07). |
#
# ## Parameters to calibrate
#
# The vector of parameters to calibrate is:
# $$
# \theta = (R,C,\gamma).
# $$
#
# We set:
#
# - $R = 750\times 10^6$,
# - $C = 2750\times 10^6$,
# - $\gamma = 10$.
#
# ## Observations
#
# In order to create a calibration problem, we make the hypothesis that the strain has the following distribution:
# $$
# \epsilon \sim Uniform(0,0.07).
# $$
#
# Moreover, we consider a gaussian noise on the observed constraint:
# $$
# \epsilon_\sigma \sim \mathcal{N} \left(0,10\times 10^6\right)
# $$
#
# and we make the hypothesis that the observation errors are independent.
# We set the number of observations to:
# $$
# n = 100.
# $$
#
# We generate a Monte-Carlo samplg with size $n$:
# $$
# \sigma_i = G(\epsilon_i,R,C,\gamma) + (\epsilon_\sigma)_i,
# $$
#
# for $i = 1,..., n$.
# The observations are the pairs $\{(\epsilon_i,\sigma_i)\}_{i=1,...,n}$, i.e. each observation is a couple made of the strain and the corresponding stress.
#
# ## Thanks to
#
# - Antoine Dumas, Phimeca
#
#
# ## References
#
# - J. Lemaitre and J. L. Chaboche (2002) "Mechanics of solid materials" Cambridge University Press.

# %% [markdown]
# ## Generate the observations

# %%
import numpy as np
import openturns as ot

# %% [markdown]
# Define the model.

# %%
def modelChaboche(X):
    strain, R, C, gamma = X
    stress = R + C * (1.0 - np.exp(-gamma * strain)) / gamma
    return [stress]

# %% [markdown]
# Create the Python function.

# %%
g = ot.PythonFunction(4, 1, modelChaboche)

# %% [markdown]
# Define the random vector.

# %%
Strain = ot.Uniform(0.0, 0.07)
unknownR = 750e6
unknownC = 2750e6
unknownGamma = 10.0
R = ot.Dirac(unknownR)
C = ot.Dirac(unknownC)
Gamma = ot.Dirac(unknownGamma)

Strain.setDescription(["Strain"])
R.setDescription(["R"])
C.setDescription(["C"])
Gamma.setDescription(["Gamma"])

# %% [markdown]
# Create the joint input distribution function.

# %%
inputDistribution = ot.ComposedDistribution([Strain, R, C, Gamma])

# %% [markdown]
# Create the Monte-Carlo sample.

# %%
sampleSize = 100
inputSample = inputDistribution.getSample(sampleSize)
outputStress = g(inputSample)
outputStress[0:5]
# Out:
# class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=5 dimension=1 description=[y0] data=[[8.48052e+08],[8.76764e+08],[7.74846e+08],[7.56186e+08],[8.09312e+08]]

# %% [markdown]
# Plot the histogram of the output.

# %%
histoGraph = ot.HistogramFactory().build(outputStress / 1.0e6).drawPDF()
histoGraph.setTitle("Histogram of the sample stress")
histoGraph.setXTitle("Stress (MPa)")
histoGraph.setLegends([""])
histoGraph
# Out:
# class=Graph name=y0 PDF implementation=class=GraphImplementation name=y0 PDF title=Histogram of the sample stress xTitle=Stress (MPa) yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=24 dimension=2 data=[[736.658,0],[750.405,0],[750.405,0],[750.405,0.00400064],[777.901,0.00400064],[777.901,0],[777.901,0],[777.901,0.00545542],[805.397,0.00545542],[805.397,0],[805.397,0],[805.397,0.00763759],[832.892,0.00763759],[832.892,0],[832.892,0],[832.892,0.00836497],[860.388,0.00836497],[860.388,0],[860.388,0],[860.388,0.0109108],[887.883,0.0109108],[887.883,0],[887.883,0],[901.631,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# Generate observation noise.

# %%
stressObservationNoiseSigma = 10.0e6  # (Pa)
noiseSigma = ot.Normal(0.0, stressObservationNoiseSigma)
sampleNoiseH = noiseSigma.getSample(sampleSize)
observedStress = outputStress + sampleNoiseH

# %%
observedStrain = inputSample[:, 0]

# %%
graph = ot.Graph("Observations", "Strain", "Stress (MPa)", True)
cloud = ot.Cloud(observedStrain, observedStress / 1.0e6)
graph.add(cloud)
graph
# Out:
# class=Graph name=Observations implementation=class=GraphImplementation name=Observations title=Observations xTitle=Strain yTitle=Stress (MPa) axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[0.0440914,848.093],[0.0617964,903.326],[0.00946934,777.549],[0.00227519,760.677],[0.024294,822.587],[0.0678596,890.947],[0.0644476,883.664],[0.0352128,825.546],[0.00442443,762.811],[0.020493,792.298],[0.0500067,870.199],[0.0268353,814.363],[0.0261637,803.505],[0.0516088,850.835],[0.0618452,874.33],[0.0206496,799.263],[0.0649957,869.818],[0.0574568,859.171],[0.0479202,846.773],[0.0579619,856.455],[0.0251862,812.211],[0.0668322,876.685],[0.0412031,857.669],[0.0127427,790.093],[0.00600495,748.026],[0.0462509,846.622],[0.0147309,787.415],[0.027036,824.144],[0.00171916,757.264],[0.0293243,813.96],[0.0687289,889.151],[0.0641292,875.303],[0.0668922,886.471],[0.0331065,834.329],[0.0181903,792.798],[0.0462938,860.506],[0.0342842,802.951],[0.0327967,842.009],[0.00777544,780.849],[0.0241723,796.711],[0.0459184,852.533],[0.0472562,863.019],[0.0685286,896.653],[0.0452434,849.383],[0.00449486,766.864],[0.0541114,870.377],[0.069594,882.246],[0.00581514,759.357],[0.0157407,785.593],[0.0211834,796.851],[0.0152048,768.687],[0.0440765,848.354],[0.0406107,866.931],[0.0326962,817.679],[0.0487196,840.885],[0.051877,848.312],[0.0655773,884.568],[0.0610014,844.607],[0.0275226,816.297],[0.0440474,835.4],[0.0639471,890.195],[0.0639381,872.24],[0.011157,781.207],[0.0381107,847.599],[0.0142557,789.853],[0.0599057,869.052],[0.0304555,817.546],[0.0253165,814.827],[0.000147533,748.728],[0.0167604,822.562],[0.0178609,804.401],[0.0414074,849.357],[0.0118452,786.836],[0.0684134,870.88],[0.0338094,804.823],[0.0496515,864.251],[0.0670561,877.797],[0.0492112,849.367],[0.0574125,874.502],[0.0337317,824.184],[0.0144598,805.627],[0.0525836,864.655],[0.0647872,898.386],[0.0445146,843.365],[0.0421513,837.218],[0.0491053,851.623],[0.00555904,742.284],[0.0176633,788.562],[0.0473883,850.644],[0.0250917,793.199],[0.029409,813.22],[0.0224948,806.008],[0.055902,876.501],[0.0402894,826.565],[0.0230103,803.338],[0.0680178,898.337],[0.0362339,829.32],[0.00754743,751.068],[0.0635452,874.19],[0.0524821,868.765]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %% [markdown]
# ## Set the calibration parameters

# %% [markdown]
# Define the value of the reference values of the $\theta$ parameter. In the bayesian framework, this is called the mean of the *prior* gaussian distribution. In the data assimilation framework, this is called the *background*.

# %%
R = 700e6  # Exact : 750e6
C = 2500e6  # Exact : 2750e6
Gamma = 8.0  # Exact : 10
thetaPrior = ot.Point([R, C, Gamma])

# %% [markdown]
# The following statement create the calibrated function from the model. The calibrated parameters R, C, Gamma are at indices 1, 2, 3 in the inputs arguments of the model.

# %%
calibratedIndices = [1, 2, 3]
mycf = ot.ParametricFunction(g, calibratedIndices, thetaPrior)

# %% [markdown]
# ## Gaussian calibration parameters

# %% [markdown]
# The standard deviation of the observations errors.

# %%
sigmaStress = 1.0e7  # (Pa)

# %% [markdown]
# Define the covariance matrix of the output Y of the model.

# %%
errorCovariance = ot.CovarianceMatrix(1)  # R
errorCovariance[0, 0] = sigmaStress ** 2

# %% [markdown]
# Define the covariance matrix of the parameters $\theta$ to calibrate.

# %%
sigmaR = 0.1 * R
sigmaC = 0.1 * C
sigmaGamma = 0.1 * Gamma

# %%
sigma = ot.CovarianceMatrix(3)  # B
sigma[0, 0] = sigmaR ** 2
sigma[1, 1] = sigmaC ** 2
sigma[2, 2] = sigmaGamma ** 2
sigma
# Out:
# class=CovarianceMatrix dimension=3 implementation=class=MatrixImplementation name=Unnamed rows=3 columns=3 values=[4.9e+15,0,0,0,6.25e+16,0,0,0,0.64]

# %% [markdown]
# ## Gaussian linear calibration

# %% [markdown]
# The `GaussianLinearCalibration` class performs the gaussian linear calibration by linearizing the model in the neighbourhood of the prior.

# %%
algo = ot.GaussianLinearCalibration(
    mycf, observedStrain, observedStress, thetaPrior, sigma, errorCovariance
)

# %% [markdown]
# The `run` method computes the solution of the problem.

# %%
algo.run()

# %%
calibrationResult = algo.getResult()

# %% [markdown]
# ## Analysis of the results

# %% [markdown]
# The `getParameterMAP` method returns the maximum of the posterior distribution of $\theta$.

# %%
thetaMAP = calibrationResult.getParameterMAP()
thetaMAP
# Out:
# class=Point name=Unnamed dimension=3 values=[7.49913e+08,2.60377e+09,8.15823]

# %% [markdown]
# We can compute a 95% confidence interval of the parameter $\theta^\star$.

# %%
thetaPosterior = calibrationResult.getParameterPosterior()
thetaPosterior.computeBilateralConfidenceIntervalWithMarginalProbability(0.95)[0]
# Out:
# class=Interval name=Unnamed dimension=3 lower bound=class=Point name=Unnamed dimension=3 values=[7.44644e+08,2.40757e+09,6.45765] upper bound=class=Point name=Unnamed dimension=3 values=[7.55183e+08,2.79997e+09,9.85881] finite lower bound=[1,1,1] finite upper bound=[1,1,1]

# %% [markdown]
# We can see that all three parameters are estimated with a large confidence interval.

# %%
graph = calibrationResult.drawObservationsVsInputs()
graph.setLegendPosition("topleft")
graph
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=Strain yTitle=y0 axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Observations data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[0.0440914,8.48093e+08],[0.0617964,9.03326e+08],[0.00946934,7.77549e+08],[0.00227519,7.60677e+08],[0.024294,8.22587e+08],[0.0678596,8.90947e+08],[0.0644476,8.83664e+08],[0.0352128,8.25546e+08],[0.00442443,7.62811e+08],[0.020493,7.92298e+08],[0.0500067,8.70199e+08],[0.0268353,8.14363e+08],[0.0261637,8.03505e+08],[0.0516088,8.50835e+08],[0.0618452,8.7433e+08],[0.0206496,7.99263e+08],[0.0649957,8.69818e+08],[0.0574568,8.59171e+08],[0.0479202,8.46773e+08],[0.0579619,8.56455e+08],[0.0251862,8.12211e+08],[0.0668322,8.76685e+08],[0.0412031,8.57669e+08],[0.0127427,7.90093e+08],[0.00600495,7.48026e+08],[0.0462509,8.46622e+08],[0.0147309,7.87415e+08],[0.027036,8.24144e+08],[0.00171916,7.57264e+08],[0.0293243,8.1396e+08],[0.0687289,8.89151e+08],[0.0641292,8.75303e+08],[0.0668922,8.86471e+08],[0.0331065,8.34329e+08],[0.0181903,7.92798e+08],[0.0462938,8.60506e+08],[0.0342842,8.02951e+08],[0.0327967,8.42009e+08],[0.00777544,7.80849e+08],[0.0241723,7.96711e+08],[0.0459184,8.52533e+08],[0.0472562,8.63019e+08],[0.0685286,8.96653e+08],[0.0452434,8.49383e+08],[0.00449486,7.66864e+08],[0.0541114,8.70377e+08],[0.069594,8.82246e+08],[0.00581514,7.59357e+08],[0.0157407,7.85593e+08],[0.0211834,7.96851e+08],[0.0152048,7.68687e+08],[0.0440765,8.48354e+08],[0.0406107,8.66931e+08],[0.0326962,8.17679e+08],[0.0487196,8.40885e+08],[0.051877,8.48312e+08],[0.0655773,8.84568e+08],[0.0610014,8.44607e+08],[0.0275226,8.16297e+08],[0.0440474,8.354e+08],[0.0639471,8.90195e+08],[0.0639381,8.7224e+08],[0.011157,7.81207e+08],[0.0381107,8.47599e+08],[0.0142557,7.89853e+08],[0.0599057,8.69052e+08],[0.0304555,8.17546e+08],[0.0253165,8.14827e+08],[0.000147533,7.48728e+08],[0.0167604,8.22562e+08],[0.0178609,8.04401e+08],[0.0414074,8.49357e+08],[0.0118452,7.86836e+08],[0.0684134,8.7088e+08],[0.0338094,8.04823e+08],[0.0496515,8.64251e+08],[0.0670561,8.77797e+08],[0.0492112,8.49367e+08],[0.0574125,8.74502e+08],[0.0337317,8.24184e+08],[0.0144598,8.05627e+08],[0.0525836,8.64655e+08],[0.0647872,8.98386e+08],[0.0445146,8.43365e+08],[0.0421513,8.37218e+08],[0.0491053,8.51623e+08],[0.00555904,7.42284e+08],[0.0176633,7.88562e+08],[0.0473883,8.50644e+08],[0.0250917,7.93199e+08],[0.029409,8.1322e+08],[0.0224948,8.06008e+08],[0.055902,8.76501e+08],[0.0402894,8.26565e+08],[0.0230103,8.03338e+08],[0.0680178,8.98337e+08],[0.0362339,8.2932e+08],[0.00754743,7.51068e+08],[0.0635452,8.7419e+08],[0.0524821,8.68765e+08]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[0.0440914,7.92886e+08],[0.0617964,8.21889e+08],[0.00946934,7.22799e+08],[0.00227519,7.05637e+08],[0.024294,7.55197e+08],[0.0678596,8.30914e+08],[0.0644476,8.25889e+08],[0.0352128,7.76719e+08],[0.00442443,7.10868e+08],[0.020493,7.47253e+08],[0.0500067,8.03036e+08],[0.0268353,7.60376e+08],[0.0261637,7.59018e+08],[0.0516088,8.05704e+08],[0.0618452,8.21964e+08],[0.0206496,7.47585e+08],[0.0649957,8.26706e+08],[0.0574568,8.15156e+08],[0.0479202,7.99511e+08],[0.0579619,8.15951e+08],[0.0251862,7.57027e+08],[0.0668322,8.29416e+08],[0.0412031,7.87752e+08],[0.0127427,7.30287e+08],[0.00600495,7.14657e+08],[0.0462509,7.96647e+08],[0.0147309,7.3474e+08],[0.027036,7.6078e+08],[0.00171916,7.04268e+08],[0.0293243,7.65346e+08],[0.0687289,8.32173e+08],[0.0641292,8.25414e+08],[0.0668922,8. ...

# %% [markdown]
# We see that there is a good fit after calibration, since the predictions after calibration (i.e. the green crosses) are close to the observations (i.e. the blue crosses).

# %%
calibrationResult.drawObservationsVsPredictions()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=y0 observations yTitle=y0 predictions axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[7.42284e+08,7.42284e+08],[9.03326e+08,9.03326e+08]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[8.48093e+08,7.92886e+08],[9.03326e+08,8.21889e+08],[7.77549e+08,7.22799e+08],[7.60677e+08,7.05637e+08],[8.22587e+08,7.55197e+08],[8.90947e+08,8.30914e+08],[8.83664e+08,8.25889e+08],[8.25546e+08,7.76719e+08],[7.62811e+08,7.10868e+08],[7.92298e+08,7.47253e+08],[8.70199e+08,8.03036e+08],[8.14363e+08,7.60376e+08],[8.03505e+08,7.59018e+08],[8.50835e+08,8.05704e+08],[8.7433e+08,8.21964e+08],[7.99263e+08,7.47585e+08],[8.69818e+08,8.26706e+08],[8.59171e+08,8.15156e+08],[8.46773e+08,7.99511e+08],[8.56455e+08,8.15951e+08],[8.12211e+08,7.57027e+08],[8.76685e+08,8.29416e+08],[8.57669e+08,7.87752e+08],[7.90093e+08,7.30287e+08],[7.48026e+08,7.14657e+08],[8.46622e+08,7.96647e+08],[7.87415e+08,7.3474e+08],[8.24144e+08,7.6078e+08],[7.57264e+08,7.04268e+08],[8.1396e+08,7.65346e+08],[8.89151e+08,8.32173e+08],[8.75303e+08,8.25414e+08],[8.86471e+08,8.29504e+08],[8.34329e+08,7.72713e+08],[7.92798e+08,7.42322e+08],[8.60506e+08,7.96721e+08],[8.02951e+08,7.74961e+08],[8.42009e+08,7.72118e+08],[7.80849e+08,7.18846e+08],[7.96711e+08,7.54947e+08],[8.52533e+08,7.96072e+08],[8.63019e+08,7.98376e+08],[8.96653e+08,8.31884e+08],[8.49383e+08,7.949e+08],[7.66864e+08,7.11038e+08],[8.70377e+08,8.09803e+08],[8.82246e+08,8.33416e+08],[7.59357e+08,7.14205e+08],[7.85593e+08,7.36975e+08],[7.96851e+08,7.48714e+08],[7.68687e+08,7.35791e+08],[8.48354e+08,7.92859e+08],[8.66931e+08,7.86684e+08],[8.17679e+08,7.71924e+08],[8.40885e+08,8.00868e+08],[8.48312e+08,8.06147e+08],[8.84568e+08,8.27568e+08],[8.44607e+08,8.20673e+08],[8.16297e+08,7.61758e+08],[8.354e+08,7.92808e+08],[8.90195e+08,8.25141e+08],[8.7224e+08,8.25127e+08],[7.81207e+08,7.26684e+08],[8.47599e+08,7.82123e+08],[7.89853e+08,7.33682e+08],[8.69052e+08,8.18984e+08],[8.17546e+08,7.67573e+08],[8.14827e+08,7.57294e+08],[7.48728e+08,7.00369e+08],[8.22562e+08,7.39213e+08],[8.04401e+08,7.41609e+08],[8.49357e+08,7.88119e+08],[7.86836e+08,7.28253e+08],[8.7088e+08,8.31717e+08],[8.04823e+08,7.74057e+08],[8.64251e+08,8.0244e+08],[8.77797e+08,8.29743e+08],[8.49367e+08,8.01699e+08],[8.74502e+08,8.15086e+08],[8.24184e+08,7.73909e+08],[8.05627e+08,7.34137e+08],[8.64655e+08,8.0731e+08],[8.98386e+08,8.26396e+08],[8.43365e+08,7.93628e+08],[8.37218e+08,7.89451e+08],[8.51623e+08,8.0152e+08],[7.42284e+08,7.13593e+08],[7.88562e+08,7.4118e+08],[8.50644e+08,7.98602e+08],[7.93199e+08,7.56834e+08],[8.1322e+08,7.65514e+08],[8.06008e+08,7.51467e+08],[8.76501e+08,8.12686e+08],[8.26565e+08,7.86103e+08],[8.03338e+08,7.52542e+08],[8.98337e+08,8.31144e+08],[8.2932e+08,7.78638e+08],[7.51068e+08,7.1831e+08],[8.7419e+08,8.24537e+08],[8.68765e+08,8.07144e+08]] color=red fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Calibrated data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[8.48093e+08,8.462e+08],[9.03326e+08,8.76197e+08],[7.77549e+08,7.73931e+08],[7.60677e+08,7.56167e+08],[8.22587e+08,8.07479e+08],[8.90947e+08,8.85747e+08],[8.83664e+08,8.80157e+08],[8.25546e+08,8.29517e+08],[7.6 ...

# %% [markdown]
# We see that there is a much better fit after calibration, since the predictions are close to the diagonal of the graphics.

# %% [markdown]
# The observation error is predicted by linearizing the problem at the prior.

# %%
observationError = calibrationResult.getObservationsError()
observationError
# Out:
# class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[0] sigma=class=Point name=Unnamed dimension=1 values=[1e+07] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1]

# %% [markdown]
# This can be compared to the residuals distribution, which is computed at the posterior.

# %%
graph = calibrationResult.drawResiduals()
graph.setLegendPosition("topleft")
graph
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Residual analysis implementation=class=GraphImplementation name=Residual analysis title=Residual analysis xTitle=y0 residuals yTitle=PDF axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-3.73116e+07,7.62234e-66],[-3.63689e+07,3.95262e-64],[-3.54263e+07,1.92789e-62],[-3.44836e+07,8.84471e-61],[-3.3541e+07,3.81669e-59],[-3.25983e+07,1.54914e-57],[-3.16557e+07,5.91422e-56],[-3.0713e+07,2.12376e-54],[-2.97703e+07,7.17327e-53],[-2.88277e+07,2.27892e-51],[-2.7885e+07,6.80996e-50],[-2.69424e+07,1.91409e-48],[-2.59997e+07,5.06035e-47],[-2.50571e+07,1.25835e-45],[-2.41144e+07,2.94323e-44],[-2.31717e+07,6.47514e-43],[-2.22291e+07,1.33991e-41],[-2.12864e+07,2.60799e-40],[-2.03438e+07,4.7746e-39],[-1.94011e+07,8.22186e-38],[-1.84585e+07,1.3317e-36],[-1.75158e+07,2.02882e-35],[-1.65731e+07,2.90725e-34],[-1.56305e+07,3.91855e-33],[-1.46878e+07,4.96786e-32],[-1.37452e+07,5.92402e-31],[-1.28025e+07,6.64456e-30],[-1.18599e+07,7.01e-29],[-1.09172e+07,6.95622e-28],[-9.97454e+06,6.4928e-27],[-9.03188e+06,5.70025e-26],[-8.08922e+06,4.70717e-25],[-7.14657e+06,3.65621e-24],[-6.20391e+06,2.67121e-23],[-5.26125e+06,1.83565e-22],[-4.3186e+06,1.18654e-21],[-3.37594e+06,7.21414e-21],[-2.43328e+06,4.12572e-20],[-1.49062e+06,2.21937e-19],[-547966,1.12301e-18],[394691,5.34516e-18],[1.33735e+06,2.39317e-17],[2.28001e+06,1.00794e-16],[3.22266e+06,3.99346e-16],[4.16532e+06,1.48848e-15],[5.10798e+06,5.21962e-15],[6.05063e+06,1.72213e-14],[6.99329e+06,5.3465e-14],[7.93595e+06,1.56208e-13],[8.87861e+06,4.29578e-13],[9.82126e+06,1.1122e-12],[1.07639e+07,2.71179e-12],[1.17066e+07,6.22922e-12],[1.26492e+07,1.34878e-11],[1.35919e+07,2.75471e-11],[1.45346e+07,5.31166e-11],[1.54772e+07,9.68076e-11],[1.64199e+07,1.67021e-10],[1.73625e+07,2.73305e-10],[1.83052e+07,4.25191e-10],[1.92478e+07,6.30752e-10],[2.01905e+07,8.9533e-10],[2.11332e+07,1.22089e-09],[2.20758e+07,1.60614e-09],[2.30185e+07,2.04721e-09],[2.39611e+07,2.53812e-09],[2.49038e+07,3.07058e-09],[2.58464e+07,3.63286e-09],[2.67891e+07,4.20828e-09],[2.77318e+07,4.77463e-09],[2.86744e+07,5.30544e-09],[2.96171e+07,5.7743e-09],[3.05597e+07,6.16182e-09],[3.15024e+07,6.46409e-09],[3.2445e+07,6.70019e-09],[3.33877e+07,6.91556e-09],[3.43304e+07,7.17907e-09],[3.5273e+07,7.57307e-09],[3.62157e+07,8.17894e-09],[3.71583e+07,9.06273e-09],[3.8101e+07,1.02663e-08],[3.90436e+07,1.18066e-08],[3.99863e+07,1.36823e-08],[4.0929e+07,1.58829e-08],[4.18716e+07,1.8392e-08],[4.28143e+07,2.11821e-08],[4.37569e+07,2.41996e-08],[4.46996e+07,2.73486e-08],[4.56422e+07,3.04823e-08],[4.65849e+07,3.34129e-08],[4.75276e+07,3.59407e-08],[4.84702e+07,3.78951e-08],[4.94129e+07,3.91731e-08],[5.03555e+07,3.97588e-08],[5.12982e+07,3.97172e-08],[5.22408e+07,3.91644e-08],[5.31835e+07,3.82301e-08],[5.41262e+07,3.70263e-08],[5.50688e+07,3.56351e-08],[5.60115e+07,3.41141e-08],[5.69541e+07,3.25098e-08],[5.78968e+07,3.08673e-08],[5.88394e+07,2.92303e-08],[5.97821e+07,2.76308e-08],[6.07248e+07,2.60785e-08],[6.16674e+07,2.4557e-08],[6.26101e+07,2.30313e-08],[6.35527e+07,2.14629e-08],[6.44954e+07,1.98265e-08],[6.5438e+07,1.812e-08],[6.63807e+07,1.63646e-08],[6.73234e+07,1.45962e-08],[6.8266e+07,1.28542e-08],[6.92087e+07,1.11724e-08],[7.01513e+07,9.5765e-09],[7.1094e+07,8.08768e-09],[7.20366e+07,6.72889e-09],[7.29793e+07,5.52921e-09],[7.3922e+07,4.52269e-09],[7.48646e+07,3.74096e-09],[7.58073e+07,3.20233e-09],[7.67499e+07,2.90148e-09],[7.76926e+07,2.80415e-09],[7.86352e+07,2.84957e-09],[7.95779e+07,2.96031e-09],[8.05206e+07,3.05722e-09],[8.14632e+07,3.0751e-09],[8.24059e+07,2.97464e-09],[8.33485e+07,2.74754e-09]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=Unnamed imple ...

# %% [markdown]
# The analysis of the distribution of the residuals (the blue line) shows that the distribution is centered on zero and symmetric. This indicates that the calibration performed well. Moreover, the distribution of the residuals is close to being gaussian.
#
# The observation error distribution (in green) is much narrower than the actual residuals distribution. This shows that the prior observations error underestimated the actual error distribution.

# %%
calibrationResult.drawParameterDistributions()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=3 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=x1 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=x1 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[6.98295e+08,5.69749e-09],[6.98832e+08,5.69838e-09],[6.99368e+08,5.69894e-09],[6.99905e+08,5.69917e-09],[7.00441e+08,5.69906e-09],[7.00978e+08,5.69862e-09],[7.01514e+08,5.69784e-09],[7.0205e+08,5.69673e-09],[7.02587e+08,5.69529e-09],[7.03123e+08,5.69351e-09],[7.0366e+08,5.69139e-09],[7.04196e+08,5.68894e-09],[7.04733e+08,5.68616e-09],[7.05269e+08,5.68305e-09],[7.05806e+08,5.67961e-09],[7.06342e+08,5.67583e-09],[7.06878e+08,5.67173e-09],[7.07415e+08,5.66729e-09],[7.07951e+08,5.66253e-09],[7.08488e+08,5.65743e-09],[7.09024e+08,5.65201e-09],[7.09561e+08,5.64627e-09],[7.10097e+08,5.64019e-09],[7.10634e+08,5.6338e-09],[7.1117e+08,5.62708e-09],[7.11706e+08,5.62003e-09],[7.12243e+08,5.61267e-09],[7.12779e+08,5.60499e-09],[7.13316e+08,5.59699e-09],[7.13852e+08,5.58867e-09],[7.14389e+08,5.58004e-09],[7.14925e+08,5.57109e-09],[7.15462e+08,5.56183e-09],[7.15998e+08,5.55226e-09],[7.16535e+08,5.54238e-09],[7.17071e+08,5.5322e-09],[7.17607e+08,5.52171e-09],[7.18144e+08,5.51091e-09],[7.1868e+08,5.49981e-09],[7.19217e+08,5.48841e-09],[7.19753e+08,5.47672e-09],[7.2029e+08,5.46473e-09],[7.20826e+08,5.45244e-09],[7.21363e+08,5.43987e-09],[7.21899e+08,5.427e-09],[7.22435e+08,5.41384e-09],[7.22972e+08,5.4004e-09],[7.23508e+08,5.38668e-09],[7.24045e+08,5.37268e-09],[7.24581e+08,5.3584e-09],[7.25118e+08,5.34384e-09],[7.25654e+08,5.32901e-09],[7.26191e+08,5.3139e-09],[7.26727e+08,5.29853e-09],[7.27263e+08,5.2829e-09],[7.278e+08,5.267e-09],[7.28336e+08,5.25084e-09],[7.28873e+08,5.23442e-09],[7.29409e+08,5.21775e-09],[7.29946e+08,5.20082e-09],[7.30482e+08,5.18365e-09],[7.31019e+08,5.16623e-09],[7.31555e+08,5.14856e-09],[7.32092e+08,5.13065e-09],[7.32628e+08,5.11251e-09],[7.33164e+08,5.09413e-09],[7.33701e+08,5.07552e-09],[7.34237e+08,5.05668e-09],[7.34774e+08,5.03761e-09],[7.3531e+08,5.01832e-09],[7.35847e+08,4.99881e-09],[7.36383e+08,4.97909e-09],[7.3692e+08,4.95915e-09],[7.37456e+08,4.939e-09],[7.37992e+08,4.91865e-09],[7.38529e+08,4.89809e-09],[7.39065e+08,4.87733e-09],[7.39602e+08,4.85637e-09],[7.40138e+08,4.83522e-09],[7.40675e+08,4.81387e-09],[7.41211e+08,4.79234e-09],[7.41748e+08,4.77063e-09],[7.42284e+08,4.74874e-09],[7.4282e+08,4.72667e-09],[7.43357e+08,4.70442e-09],[7.43893e+08,4.68201e-09],[7.4443e+08,4.65942e-09],[7.44966e+08,4.63668e-09],[7.45503e+08,4.61377e-09],[7.46039e+08,4.59071e-09],[7.46576e+08,4.5675e-09],[7.47112e+08,4.54413e-09],[7.47649e+08,4.52062e-09],[7.48185e+08,4.49697e-09],[7.48721e+08,4.47318e-09],[7.49258e+08,4.44925e-09],[7.49794e+08,4.42519e-09],[7.50331e+08,4.40101e-09],[7.50867e+08,4.37669e-09],[7.51404e+08,4.35226e-09],[7.5194e+08,4.32771e-09],[7.52477e+08,4.30304e-09],[7.53013e+08,4.27827e-09],[7.53549e+08,4.25339e-09],[7.54086e+08,4.2284e-09],[7.54622e+08,4.20331e-09],[7.55159e+08,4.17813e-09],[7.55695e+08,4.15285e-09],[7.56232e+08,4.12749e-09],[7.56768e+08,4.10203e-09],[7.57305e+08,4.0765e-09],[7.57841e+08,4.05089e-09],[7.58377e+08,4.0252e-09],[7.58914e+08,3.99944e-09],[7.5945e+08,3.97361e-09],[7.59987e+08,3.94771e-09],[7.60523e+08,3.92176e-09],[7.6106e+08,3.89574e-09],[7.61596e+08,3.86967e-09],[7.62133e+08,3.84355e-09],[7.62669e+08,3.81738e-09],[7.63206e+08,3.79117e-09],[7.63742e+08,3.76492e-09],[7.64278e+08,3.73863e-09],[7.64815e+08,3.7123e-09],[7.65351e+08,3.68594e-09],[7.65888e+08,3.65956e-09],[7.66424e+08,3.63315e-09],[7.66961e+08,3.60672e-09]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation nam ...

# %% [markdown]
# We see that the prior and posterior distribution are close to each other for the $C$ variable: the observations did not convey much information for this variable.

# %% [markdown]
# ## Gaussian nonlinear calibration

# %% [markdown]
# The `GaussianNonLinearCalibration` class performs the gaussian nonlinear calibration.

# %%
algo = ot.GaussianNonLinearCalibration(
    mycf, observedStrain, observedStress, thetaPrior, sigma, errorCovariance
)

# %% [markdown]
# The `run` method computes the solution of the problem.

# %%
algo.run()

# %%
calibrationResult = algo.getResult()

# %% [markdown]
# ## Analysis of the results

# %% [markdown]
# The `getParameterMAP` method returns the maximum of the posterior distribution of $\theta$.

# %%
thetaMAP = calibrationResult.getParameterMAP()
thetaMAP
# Out:
# class=Point name=Unnamed dimension=3 values=[7.50418e+08,2.58129e+09,8.02849]

# %% [markdown]
# We can compute a 95% confidence interval of the parameter $\theta^\star$.

# %%
thetaPosterior = calibrationResult.getParameterPosterior()
thetaPosterior.computeBilateralConfidenceIntervalWithMarginalProbability(0.95)[0]
# Out:
# class=Interval name=Unnamed dimension=3 lower bound=class=Point name=Unnamed dimension=3 values=[7.43884e+08,2.40367e+09,7.46417] upper bound=class=Point name=Unnamed dimension=3 values=[7.56864e+08,2.76866e+09,8.65764] finite lower bound=[1,1,1] finite upper bound=[1,1,1]

# %% [markdown]
# We can see that all three parameters are estimated with a large confidence interval.

# %%
graph = calibrationResult.drawObservationsVsInputs()
graph.setLegendPosition("topleft")
graph
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=Strain yTitle=y0 axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Observations data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[0.0440914,8.48093e+08],[0.0617964,9.03326e+08],[0.00946934,7.77549e+08],[0.00227519,7.60677e+08],[0.024294,8.22587e+08],[0.0678596,8.90947e+08],[0.0644476,8.83664e+08],[0.0352128,8.25546e+08],[0.00442443,7.62811e+08],[0.020493,7.92298e+08],[0.0500067,8.70199e+08],[0.0268353,8.14363e+08],[0.0261637,8.03505e+08],[0.0516088,8.50835e+08],[0.0618452,8.7433e+08],[0.0206496,7.99263e+08],[0.0649957,8.69818e+08],[0.0574568,8.59171e+08],[0.0479202,8.46773e+08],[0.0579619,8.56455e+08],[0.0251862,8.12211e+08],[0.0668322,8.76685e+08],[0.0412031,8.57669e+08],[0.0127427,7.90093e+08],[0.00600495,7.48026e+08],[0.0462509,8.46622e+08],[0.0147309,7.87415e+08],[0.027036,8.24144e+08],[0.00171916,7.57264e+08],[0.0293243,8.1396e+08],[0.0687289,8.89151e+08],[0.0641292,8.75303e+08],[0.0668922,8.86471e+08],[0.0331065,8.34329e+08],[0.0181903,7.92798e+08],[0.0462938,8.60506e+08],[0.0342842,8.02951e+08],[0.0327967,8.42009e+08],[0.00777544,7.80849e+08],[0.0241723,7.96711e+08],[0.0459184,8.52533e+08],[0.0472562,8.63019e+08],[0.0685286,8.96653e+08],[0.0452434,8.49383e+08],[0.00449486,7.66864e+08],[0.0541114,8.70377e+08],[0.069594,8.82246e+08],[0.00581514,7.59357e+08],[0.0157407,7.85593e+08],[0.0211834,7.96851e+08],[0.0152048,7.68687e+08],[0.0440765,8.48354e+08],[0.0406107,8.66931e+08],[0.0326962,8.17679e+08],[0.0487196,8.40885e+08],[0.051877,8.48312e+08],[0.0655773,8.84568e+08],[0.0610014,8.44607e+08],[0.0275226,8.16297e+08],[0.0440474,8.354e+08],[0.0639471,8.90195e+08],[0.0639381,8.7224e+08],[0.011157,7.81207e+08],[0.0381107,8.47599e+08],[0.0142557,7.89853e+08],[0.0599057,8.69052e+08],[0.0304555,8.17546e+08],[0.0253165,8.14827e+08],[0.000147533,7.48728e+08],[0.0167604,8.22562e+08],[0.0178609,8.04401e+08],[0.0414074,8.49357e+08],[0.0118452,7.86836e+08],[0.0684134,8.7088e+08],[0.0338094,8.04823e+08],[0.0496515,8.64251e+08],[0.0670561,8.77797e+08],[0.0492112,8.49367e+08],[0.0574125,8.74502e+08],[0.0337317,8.24184e+08],[0.0144598,8.05627e+08],[0.0525836,8.64655e+08],[0.0647872,8.98386e+08],[0.0445146,8.43365e+08],[0.0421513,8.37218e+08],[0.0491053,8.51623e+08],[0.00555904,7.42284e+08],[0.0176633,7.88562e+08],[0.0473883,8.50644e+08],[0.0250917,7.93199e+08],[0.029409,8.1322e+08],[0.0224948,8.06008e+08],[0.055902,8.76501e+08],[0.0402894,8.26565e+08],[0.0230103,8.03338e+08],[0.0680178,8.98337e+08],[0.0362339,8.2932e+08],[0.00754743,7.51068e+08],[0.0635452,8.7419e+08],[0.0524821,8.68765e+08]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[0.0440914,7.92886e+08],[0.0617964,8.21889e+08],[0.00946934,7.22799e+08],[0.00227519,7.05637e+08],[0.024294,7.55197e+08],[0.0678596,8.30914e+08],[0.0644476,8.25889e+08],[0.0352128,7.76719e+08],[0.00442443,7.10868e+08],[0.020493,7.47253e+08],[0.0500067,8.03036e+08],[0.0268353,7.60376e+08],[0.0261637,7.59018e+08],[0.0516088,8.05704e+08],[0.0618452,8.21964e+08],[0.0206496,7.47585e+08],[0.0649957,8.26706e+08],[0.0574568,8.15156e+08],[0.0479202,7.99511e+08],[0.0579619,8.15951e+08],[0.0251862,7.57027e+08],[0.0668322,8.29416e+08],[0.0412031,7.87752e+08],[0.0127427,7.30287e+08],[0.00600495,7.14657e+08],[0.0462509,7.96647e+08],[0.0147309,7.3474e+08],[0.027036,7.6078e+08],[0.00171916,7.04268e+08],[0.0293243,7.65346e+08],[0.0687289,8.32173e+08],[0.0641292,8.25414e+08],[0.0668922,8. ...

# %% [markdown]
# We see that there is a good fit after calibration, since the predictions after calibration (i.e. the green crosses) are close to the observations (i.e. the blue crosses).

# %%
calibrationResult.drawObservationsVsPredictions()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=y0 observations yTitle=y0 predictions axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[7.42284e+08,7.42284e+08],[9.03326e+08,9.03326e+08]] color=blue fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[8.48093e+08,7.92886e+08],[9.03326e+08,8.21889e+08],[7.77549e+08,7.22799e+08],[7.60677e+08,7.05637e+08],[8.22587e+08,7.55197e+08],[8.90947e+08,8.30914e+08],[8.83664e+08,8.25889e+08],[8.25546e+08,7.76719e+08],[7.62811e+08,7.10868e+08],[7.92298e+08,7.47253e+08],[8.70199e+08,8.03036e+08],[8.14363e+08,7.60376e+08],[8.03505e+08,7.59018e+08],[8.50835e+08,8.05704e+08],[8.7433e+08,8.21964e+08],[7.99263e+08,7.47585e+08],[8.69818e+08,8.26706e+08],[8.59171e+08,8.15156e+08],[8.46773e+08,7.99511e+08],[8.56455e+08,8.15951e+08],[8.12211e+08,7.57027e+08],[8.76685e+08,8.29416e+08],[8.57669e+08,7.87752e+08],[7.90093e+08,7.30287e+08],[7.48026e+08,7.14657e+08],[8.46622e+08,7.96647e+08],[7.87415e+08,7.3474e+08],[8.24144e+08,7.6078e+08],[7.57264e+08,7.04268e+08],[8.1396e+08,7.65346e+08],[8.89151e+08,8.32173e+08],[8.75303e+08,8.25414e+08],[8.86471e+08,8.29504e+08],[8.34329e+08,7.72713e+08],[7.92798e+08,7.42322e+08],[8.60506e+08,7.96721e+08],[8.02951e+08,7.74961e+08],[8.42009e+08,7.72118e+08],[7.80849e+08,7.18846e+08],[7.96711e+08,7.54947e+08],[8.52533e+08,7.96072e+08],[8.63019e+08,7.98376e+08],[8.96653e+08,8.31884e+08],[8.49383e+08,7.949e+08],[7.66864e+08,7.11038e+08],[8.70377e+08,8.09803e+08],[8.82246e+08,8.33416e+08],[7.59357e+08,7.14205e+08],[7.85593e+08,7.36975e+08],[7.96851e+08,7.48714e+08],[7.68687e+08,7.35791e+08],[8.48354e+08,7.92859e+08],[8.66931e+08,7.86684e+08],[8.17679e+08,7.71924e+08],[8.40885e+08,8.00868e+08],[8.48312e+08,8.06147e+08],[8.84568e+08,8.27568e+08],[8.44607e+08,8.20673e+08],[8.16297e+08,7.61758e+08],[8.354e+08,7.92808e+08],[8.90195e+08,8.25141e+08],[8.7224e+08,8.25127e+08],[7.81207e+08,7.26684e+08],[8.47599e+08,7.82123e+08],[7.89853e+08,7.33682e+08],[8.69052e+08,8.18984e+08],[8.17546e+08,7.67573e+08],[8.14827e+08,7.57294e+08],[7.48728e+08,7.00369e+08],[8.22562e+08,7.39213e+08],[8.04401e+08,7.41609e+08],[8.49357e+08,7.88119e+08],[7.86836e+08,7.28253e+08],[8.7088e+08,8.31717e+08],[8.04823e+08,7.74057e+08],[8.64251e+08,8.0244e+08],[8.77797e+08,8.29743e+08],[8.49367e+08,8.01699e+08],[8.74502e+08,8.15086e+08],[8.24184e+08,7.73909e+08],[8.05627e+08,7.34137e+08],[8.64655e+08,8.0731e+08],[8.98386e+08,8.26396e+08],[8.43365e+08,7.93628e+08],[8.37218e+08,7.89451e+08],[8.51623e+08,8.0152e+08],[7.42284e+08,7.13593e+08],[7.88562e+08,7.4118e+08],[8.50644e+08,7.98602e+08],[7.93199e+08,7.56834e+08],[8.1322e+08,7.65514e+08],[8.06008e+08,7.51467e+08],[8.76501e+08,8.12686e+08],[8.26565e+08,7.86103e+08],[8.03338e+08,7.52542e+08],[8.98337e+08,8.31144e+08],[8.2932e+08,7.78638e+08],[7.51068e+08,7.1831e+08],[8.7419e+08,8.24537e+08],[8.68765e+08,8.07144e+08]] color=red fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Calibrated data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[8.48093e+08,8.4626e+08],[9.03326e+08,8.75975e+08],[7.77549e+08,7.74351e+08],[7.60677e+08,7.56723e+08],[8.22587e+08,8.07609e+08],[8.90947e+08,8.85215e+08],[8.83664e+08,8.80071e+08],[8.25546e+08,8.29686e+08],[7. ...

# %% [markdown]
# We see that there is a much better fit after calibration, since the predictions are close to the diagonal of the graphics.

# %% [markdown]
# The observation error is predicted by bootstraping the problem at the posterior.

# %%
observationError = calibrationResult.getObservationsError()
observationError
# Out:
# class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[-7381.55] sigma=class=Point name=Unnamed dimension=1 values=[1e+07] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1]

# %% [markdown]
# This can be compared to the residuals distribution, which is computed at the posterior.

# %%
calibrationResult.drawResiduals()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Residual analysis implementation=class=GraphImplementation name=Residual analysis title=Residual analysis xTitle=y0 residuals yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Initial data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-3.7319e+07,7.38848e-66],[-3.63763e+07,3.83411e-64],[-3.54336e+07,1.87142e-62],[-3.44908e+07,8.59169e-61],[-3.35481e+07,3.71008e-59],[-3.26054e+07,1.50691e-57],[-3.16627e+07,5.75692e-56],[-3.072e+07,2.06867e-54],[-2.97773e+07,6.99185e-53],[-2.88345e+07,2.22275e-51],[-2.78918e+07,6.64644e-50],[-2.69491e+07,1.86933e-48],[-2.60064e+07,4.94517e-47],[-2.50637e+07,1.23048e-45],[-2.4121e+07,2.87984e-44],[-2.31783e+07,6.33958e-43],[-2.22355e+07,1.31266e-41],[-2.12928e+07,2.55647e-40],[-2.03501e+07,4.68305e-39],[-1.94074e+07,8.06893e-38],[-1.84647e+07,1.30768e-36],[-1.7522e+07,1.99337e-35],[-1.65793e+07,2.85806e-34],[-1.56365e+07,3.85437e-33],[-1.46938e+07,4.88918e-32],[-1.37511e+07,5.83333e-31],[-1.28084e+07,6.54632e-30],[-1.18657e+07,6.90999e-29],[-1.0923e+07,6.86052e-28],[-9.98025e+06,6.40673e-27],[-9.03753e+06,5.62752e-26],[-8.09482e+06,4.64941e-25],[-7.1521e+06,3.6131e-24],[-6.20939e+06,2.64098e-23],[-5.26667e+06,1.81574e-22],[-4.32396e+06,1.17421e-21],[-3.38124e+06,7.14245e-21],[-2.43853e+06,4.08655e-20],[-1.49581e+06,2.19928e-19],[-553099,1.11332e-18],[389616,5.30132e-18],[1.33233e+06,2.37454e-17],[2.27505e+06,1.0005e-16],[3.21776e+06,3.9656e-16],[4.16048e+06,1.47868e-15],[5.10319e+06,5.18727e-15],[6.04591e+06,1.71211e-14],[6.98862e+06,5.31737e-14],[7.93134e+06,1.55413e-13],[8.87405e+06,4.27545e-13],[9.81677e+06,1.10732e-12],[1.07595e+07,2.70081e-12],[1.17022e+07,6.20603e-12],[1.26449e+07,1.34419e-11],[1.35876e+07,2.74618e-11],[1.45303e+07,5.29677e-11],[1.54731e+07,9.65637e-11],[1.64158e+07,1.66645e-10],[1.73585e+07,2.72759e-10],[1.83012e+07,4.24442e-10],[1.92439e+07,6.29778e-10],[2.01866e+07,8.94121e-10],[2.11293e+07,1.21945e-09],[2.20721e+07,1.60449e-09],[2.30148e+07,2.04538e-09],[2.39575e+07,2.53614e-09],[2.49002e+07,3.0685e-09],[2.58429e+07,3.63072e-09],[2.67856e+07,4.20617e-09],[2.77284e+07,4.77263e-09],[2.86711e+07,5.30365e-09],[2.96138e+07,5.7728e-09],[3.05565e+07,6.16064e-09],[3.14992e+07,6.4632e-09],[3.24419e+07,6.69947e-09],[3.33846e+07,6.91482e-09],[3.43274e+07,7.17807e-09],[3.52701e+07,7.57156e-09],[3.62128e+07,8.17669e-09],[3.71555e+07,9.05962e-09],[3.80982e+07,1.02623e-08],[3.90409e+07,1.18016e-08],[3.99836e+07,1.36766e-08],[4.09264e+07,1.58764e-08],[4.18691e+07,1.83849e-08],[4.28118e+07,2.11744e-08],[4.37545e+07,2.41916e-08],[4.46972e+07,2.73406e-08],[4.56399e+07,3.04748e-08],[4.65827e+07,3.34063e-08],[4.75254e+07,3.59354e-08],[4.84681e+07,3.78915e-08],[4.94108e+07,3.91711e-08],[5.03535e+07,3.97583e-08],[5.12962e+07,3.97178e-08],[5.22389e+07,3.9166e-08],[5.31817e+07,3.82322e-08],[5.41244e+07,3.70288e-08],[5.50671e+07,3.56378e-08],[5.60098e+07,3.41169e-08],[5.69525e+07,3.25126e-08],[5.78952e+07,3.087e-08],[5.88379e+07,2.92329e-08],[5.97807e+07,2.76332e-08],[6.07234e+07,2.60808e-08],[6.16661e+07,2.45592e-08],[6.26088e+07,2.30334e-08],[6.35515e+07,2.14649e-08],[6.44942e+07,1.98285e-08],[6.5437e+07,1.8122e-08],[6.63797e+07,1.63665e-08],[6.73224e+07,1.4598e-08],[6.82651e+07,1.28558e-08],[6.92078e+07,1.11739e-08],[7.01505e+07,9.57782e-09],[7.10932e+07,8.08881e-09],[7.2036e+07,6.72983e-09],[7.29787e+07,5.52996e-09],[7.39214e+07,4.52324e-09],[7.48641e+07,3.74132e-09],[7.58068e+07,3.20254e-09],[7.67495e+07,2.90156e-09],[7.76922e+07,2.80416e-09],[7.8635e+07,2.84954e-09],[7.95777e+07,2.96028e-09],[8.05204e+07,3.05721e-09],[8.14631e+07,3.07511e-09],[8.24058e+07,2.97465e-09],[8.33485e+07,2.74754e-09]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=Unnam ...

# %% [markdown]
# The analysis of the distribution of the residuals (the blue line) shows that the distribution is approximately centered on zero and symmetric. This indicates that the calibration performed well. Moreover, the distribution of the residuals is close to being gaussian.
#
# The prior observation error distribution (in green) is much narrower than the actual residuals distribution. This shows that the prior observation error distribution underestimated the actual errors.

# %%
calibrationResult.drawParameterDistributions()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=3 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=x1 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=x1 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[6.98073e+08,5.69702e-09],[6.98636e+08,5.69809e-09],[6.99199e+08,5.6988e-09],[6.99762e+08,5.69914e-09],[7.00326e+08,5.69911e-09],[7.00889e+08,5.69872e-09],[7.01452e+08,5.69795e-09],[7.02015e+08,5.69681e-09],[7.02578e+08,5.69531e-09],[7.03142e+08,5.69344e-09],[7.03705e+08,5.6912e-09],[7.04268e+08,5.68859e-09],[7.04831e+08,5.68562e-09],[7.05394e+08,5.68228e-09],[7.05957e+08,5.67857e-09],[7.06521e+08,5.6745e-09],[7.07084e+08,5.67007e-09],[7.07647e+08,5.66527e-09],[7.0821e+08,5.66011e-09],[7.08773e+08,5.65459e-09],[7.09337e+08,5.64871e-09],[7.099e+08,5.64246e-09],[7.10463e+08,5.63587e-09],[7.11026e+08,5.62891e-09],[7.11589e+08,5.6216e-09],[7.12153e+08,5.61393e-09],[7.12716e+08,5.60592e-09],[7.13279e+08,5.59755e-09],[7.13842e+08,5.58883e-09],[7.14405e+08,5.57977e-09],[7.14968e+08,5.57035e-09],[7.15532e+08,5.5606e-09],[7.16095e+08,5.5505e-09],[7.16658e+08,5.54006e-09],[7.17221e+08,5.52929e-09],[7.17784e+08,5.51818e-09],[7.18348e+08,5.50673e-09],[7.18911e+08,5.49495e-09],[7.19474e+08,5.48284e-09],[7.20037e+08,5.47041e-09],[7.206e+08,5.45765e-09],[7.21164e+08,5.44457e-09],[7.21727e+08,5.43116e-09],[7.2229e+08,5.41744e-09],[7.22853e+08,5.4034e-09],[7.23416e+08,5.38906e-09],[7.23979e+08,5.3744e-09],[7.24543e+08,5.35943e-09],[7.25106e+08,5.34416e-09],[7.25669e+08,5.32859e-09],[7.26232e+08,5.31272e-09],[7.26795e+08,5.29656e-09],[7.27359e+08,5.2801e-09],[7.27922e+08,5.26335e-09],[7.28485e+08,5.24632e-09],[7.29048e+08,5.229e-09],[7.29611e+08,5.2114e-09],[7.30175e+08,5.19353e-09],[7.30738e+08,5.17538e-09],[7.31301e+08,5.15696e-09],[7.31864e+08,5.13827e-09],[7.32427e+08,5.11933e-09],[7.3299e+08,5.10012e-09],[7.33554e+08,5.08065e-09],[7.34117e+08,5.06093e-09],[7.3468e+08,5.04096e-09],[7.35243e+08,5.02074e-09],[7.35806e+08,5.00029e-09],[7.3637e+08,4.97959e-09],[7.36933e+08,4.95866e-09],[7.37496e+08,4.93749e-09],[7.38059e+08,4.9161e-09],[7.38622e+08,4.89448e-09],[7.39186e+08,4.87265e-09],[7.39749e+08,4.85059e-09],[7.40312e+08,4.82833e-09],[7.40875e+08,4.80585e-09],[7.41438e+08,4.78317e-09],[7.42001e+08,4.76029e-09],[7.42565e+08,4.73721e-09],[7.43128e+08,4.71394e-09],[7.43691e+08,4.69048e-09],[7.44254e+08,4.66683e-09],[7.44817e+08,4.64301e-09],[7.45381e+08,4.619e-09],[7.45944e+08,4.59482e-09],[7.46507e+08,4.57048e-09],[7.4707e+08,4.54596e-09],[7.47633e+08,4.52129e-09],[7.48197e+08,4.49646e-09],[7.4876e+08,4.47147e-09],[7.49323e+08,4.44634e-09],[7.49886e+08,4.42106e-09],[7.50449e+08,4.39564e-09],[7.51012e+08,4.37009e-09],[7.51576e+08,4.3444e-09],[7.52139e+08,4.31858e-09],[7.52702e+08,4.29264e-09],[7.53265e+08,4.26658e-09],[7.53828e+08,4.2404e-09],[7.54392e+08,4.21411e-09],[7.54955e+08,4.18771e-09],[7.55518e+08,4.16121e-09],[7.56081e+08,4.13461e-09],[7.56644e+08,4.10791e-09],[7.57208e+08,4.08112e-09],[7.57771e+08,4.05424e-09],[7.58334e+08,4.02728e-09],[7.58897e+08,4.00024e-09],[7.5946e+08,3.97313e-09],[7.60023e+08,3.94594e-09],[7.60587e+08,3.91868e-09],[7.6115e+08,3.89136e-09],[7.61713e+08,3.86398e-09],[7.62276e+08,3.83655e-09],[7.62839e+08,3.80906e-09],[7.63403e+08,3.78153e-09],[7.63966e+08,3.75395e-09],[7.64529e+08,3.72633e-09],[7.65092e+08,3.69868e-09],[7.65655e+08,3.67099e-09],[7.66219e+08,3.64327e-09],[7.66782e+08,3.61553e-09],[7.67345e+08,3.58777e-09],[7.67908e+08,3.55999e-09],[7.68471e+08,3.5322e-09],[7.69035e+08,3.5044e-09],[7.69598e+08,3.47659e-09],[7.70161e+08,3.44878e-09]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name ...

# %% [markdown]
# We see that the prior and posterior distribution are close to each other, but not superimposed: the observations significantly brought information during the calibration.

# %% [markdown]
# ## Exercise 1 : update reference parameters
#
# * Change the parameter `thetaPrior` and use the following numerical values:

# %%
R = 650e6  # Exact : 750e6
C = 2300e6  # Exact : 2750e6
Gamma = 6.0  # Exact : 10
thetaPrior = ot.Point([R, C, Gamma])

# %% [markdown]
# * How does the optimum value change when we use linear Gaussian calibration? Can you explain these differences?
# * How does the optimum value change when we use non linear Gaussian calibration? Can you explain these differences?

# %% [markdown]
# ## Exercise 2 : update the prior covariance matrix
#
# In this question, we consider the linear Gaussian calibration.
#
# * Change the `sigma` parameter and use the following numerical values:

# %%
coefficientOfVariation = 0.5
sigmaR = coefficientOfVariation * R
sigmaC = coefficientOfVariation * C
sigmaGamma = coefficientOfVariation * Gamma

# %%
sigma = ot.CovarianceMatrix(3)
sigma[0, 0] = sigmaR ** 2
sigma[1, 1] = sigmaC ** 2
sigma[2, 2] = sigmaGamma ** 2
sigma
# Out:
# class=CovarianceMatrix dimension=3 implementation=class=MatrixImplementation name=Unnamed rows=3 columns=3 values=[1.05625e+17,0,0,0,1.3225e+18,0,0,0,9]

# %% [markdown]
# * Plot the posterior distribution.
# * What are the changes in the distributions? Can you explain these changes?
# * Chante the `sigma` and use the following numerical values:

# %%
coefficientOfVariation = 0.01
sigmaR = coefficientOfVariation * R
sigmaC = coefficientOfVariation * C
sigmaGamma = coefficientOfVariation * Gamma

# %%
sigma = ot.CovarianceMatrix(3)
sigma[0, 0] = sigmaR ** 2
sigma[1, 1] = sigmaC ** 2
sigma[2, 2] = sigmaGamma ** 2
sigma
# Out:
# class=CovarianceMatrix dimension=3 implementation=class=MatrixImplementation name=Unnamed rows=3 columns=3 values=[4.225e+13,0,0,0,5.29e+14,0,0,0,0.0036]

# %% [markdown]
# * Plot the posterior distribution.
# * What are the changes in the distributions? Can you explain these changes?
# * Perform the same experiments with non linear Gaussian calibration.

# %% [markdown]
# ## Exercise 3 : change the covariance matrix of the observation error

# %% [markdown]
# * Consider the following numerical values of the observation error.

# %%
sigmaStress = 1.0e7  # (Pa) Reference value

# %%
sigmaStress = 10.0e7  # (Pa) New value #1

# %%
sigmaStress = 100.0e7  # (Pa) New value #2

# %% [markdown]
# * With Gaussian linear calibration, plot the prior and posterior distributions.
# * What are the changes in the plot? Can you explain these changes?
